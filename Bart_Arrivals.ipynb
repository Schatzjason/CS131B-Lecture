# %% [markdown]
# <a href="https://colab.research.google.com/github/Schatzjason/CS131B-Lecture/blob/main/Bart_Arrivals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

bart_url = "https://raw.githubusercontent.com/Schatzjason/CS131B-Lecture/refs/heads/main/bart_arrivals.csv"

df = pd.read_csv(
    bart_url,
    parse_dates=["expected_arrival", "actual_arrival"]
    )

df["delay"] = (
    (df["actual_arrival"] - df["expected_arrival"]).dt.total_seconds()
)

df.head()
# Out:
#   train_id station    expected_arrival      actual_arrival  delay
# 0  BART001  DUBLIN 2026-04-25 05:55:00 2026-04-25 05:55:10   10.0
# 1  BART001   W DUB 2026-04-25 05:58:00 2026-04-25 05:58:03    3.0
# 2  BART001    CVLY 2026-04-25 06:09:00 2026-04-25 06:08:53   -7.0
# 3  BART001   BFAIR 2026-04-25 06:13:00 2026-04-25 06:13:06    6.0
# 4  BART001   SLEAN 2026-04-25 06:17:00 2026-04-25 06:17:04    4.0
